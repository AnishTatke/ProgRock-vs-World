# %%
import os
import librosa
import soundfile
import audioread

import torch
import torch.nn as nn
import numpy as np

import matplotlib.pyplot as plt
import librosa.display

from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchsummary import summary

# %%
device = 'cpu'
if torch.cuda.is_available():
    device = 'cuda'
print(f"The current device used is {device}")
# Out:
# The current device used is cuda

# %%
getName = lambda s : s.split('\\')[-1]
def splitSongs(split = 0.8, path = ""):
    prog_folder = "Progressive_Rock_Songs" if path == "" else os.path.join(path + "//" + "Progressive_Rock_Songs")
    non_prog_folder = "Not_Progressive_Rock" if path == "" else os.path.join(path + "//" + "Not_Progressive_Rock")
    songs = [(i, getName(i), 1) for i in librosa.util.find_files(prog_folder)] + [(i, getName(i), 0) for i in librosa.util.find_files(non_prog_folder)]

    train_size = int(split * len(songs))
    test_size = len(songs) - train_size
    return torch.utils.data.random_split(songs, [train_size, test_size])

train_songs, validate_songs = splitSongs()

# %%
print(validate_songs.dataset[0])
# Out:
# ('C:\\Users\\tatke\\Learning\\Python\\PyTorch\\ProgProject\\Progressive_Rock_Songs\\(Disc 2) 01 - Telepathic Minds.mp3', '(Disc 2) 01 - Telepathic Minds.mp3', 1)

# %%
class SnippetProgDataset(Dataset):
    def load_file(file, snippet_length = 10, sampling_rate = 11025):
        data, sr = librosa.load(file, sr = sampling_rate)
        data, trim_shape = librosa.effects.trim(data)
        sl = sr * snippet_length
        snippets = [data[i: i+sl] for i in range(0, len(data), sl)]
        feature_snippets = []
        for idx, snippet in enumerate(snippets):
            if idx == len(snippets) - 1:
                break
            feature_snippets.append(SnippetProgDataset.extract_features(snippet))
        return feature_snippets

    def extract_features(snippet):
        magnitude = np.abs(librosa.stft(snippet))
        mel_spec = librosa.feature.melspectrogram(S = magnitude**2)
        mfcc = librosa.feature.mfcc(S = librosa.power_to_db(mel_spec))
        chroma = librosa.feature.chroma_stft(S = magnitude)
        # tempo, beat_frames = librosa.beat.beat_track(y = snippet, sr = sr)
        # cq_chroma = librosa.feature.chroma_cqt(y = snippet, sr = sr)
        # onset_env = librosa.onset.onset_strength(y = snippet, sr=sr)
        features = np.concatenate((mel_spec, mfcc, chroma), axis=0)
        return features
    
    def __init__(self, songs_array, transform = None):
        self.transform = transform
        self.songs = songs_array
        self.data = []
        self.metadata = []
        for song_path, song_name, label in tqdm(self.songs):
            song = SnippetProgDataset.load_file(song_path)
            for snippet_idx, snippet in enumerate(song):
                self.data.append((snippet, label))
                self.metadata.append({'song_name': song_name, 'snippet_idx': snippet_idx})

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        snippet, label = self.data[idx]
        metadata = self.metadata[idx]
        
        if self.transform:
            snippet = self.transform(snippet)

        return snippet, label, metadata

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])

# train_dataset = SnippetProgDataset(train_songs, transform = transform)
validate_dataset = SnippetProgDataset(validate_songs, transform = transform)
# Out:
#   1%|█                                                                                                         | 1/101 [00:01<01:48,  1.09s/it]C:\Users\tatke\AppData\Local\Temp\ipykernel_17992\38907421.py:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   data, sr = librosa.load(file, sr = sampling_rate)
# C:\Users\tatke\anaconda3\envs\MLenv\Lib\site-packages\librosa\core\audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 101/101 [02:40<00:00,  1.59s/it]

# %%
BATCH_SIZE = 32
EPOCHS = 3
LEARNING_RATE = 0.01

# %%
validate_data_loader = DataLoader(validate_dataset, batch_size = 32, shuffle = True)
v_features, v_labels, v_metadata = next(iter(validate_data_loader))
print(f"Feature batch shape: {v_features.size()}")
print(f"Labels batch shape: {v_labels.size()}")
# Out:
# Feature batch shape: torch.Size([32, 1, 160, 216])
# Labels batch shape: torch.Size([32])

# %%
class TestCNN(nn.Module):
    def __init__(self):
        super(TestCNN, self).__init__()
        
        self.conv1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size = 3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size = 3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2)
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size = 3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2)
        )
        
        self.flatten = nn.Flatten()
        
        self.fc1 = nn.Sequential(
            nn.Linear(128 * 18 * 25, 1024),
            nn.ReLU()
        )
        self.fc2 = nn.Sequential(
            nn.Linear(1024, 64),
            nn.ReLU()
        )
        self.fc3 = nn.Sequential(
            nn.Linear(64, 4),
            nn.ReLU()
        )
        self.fc4 = nn.Sequential(
            nn.Linear(4, 1),
        )

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        x = torch.nn.functional.sigmoid(self.fc4(x))
        return x

# %%
model = TestCNN()
print(summary(model, (1, 160, 216)))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# ├─Sequential: 1-1                        [-1, 32, 79, 107]         --
# |    └─Conv2d: 2-1                       [-1, 32, 158, 214]        320
# |    └─ReLU: 2-2                         [-1, 32, 158, 214]        --
# |    └─MaxPool2d: 2-3                    [-1, 32, 79, 107]         --
# ├─Sequential: 1-2                        [-1, 64, 38, 52]          --
# |    └─Conv2d: 2-4                       [-1, 64, 77, 105]         18,496
# |    └─ReLU: 2-5                         [-1, 64, 77, 105]         --
# |    └─MaxPool2d: 2-6                    [-1, 64, 38, 52]          --
# ├─Sequential: 1-3                        [-1, 128, 18, 25]         --
# |    └─Conv2d: 2-7                       [-1, 128, 36, 50]         73,856
# |    └─ReLU: 2-8                         [-1, 128, 36, 50]         --
# |    └─MaxPool2d: 2-9                    [-1, 128, 18, 25]         --
# ...

# %%
loss_fn = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE)

# %%
def validate(test_loader, test_losses):
    model.train(False)
    model.eval()
    
    test_loss = 0.0
    correct = 0
    total = 0
    predictions_dict = {}
    
    with torch.no_grad():
        for inputs, labels, metadata in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            inputs, labels = inputs.float(), labels.float()
            
            outputs = model(inputs).reshape(-1)
            test_loss += loss_fn(outputs, labels).item()
            
            predictions = (outputs > 0.5).long().reshape(-1)
            # print(predictions, metadata['song_idx'], metadata['snippet_idx'])
            for idx, song_name in enumerate(metadata['song_name']):
                if song_name not in predictions_dict:
                    predictions_dict[song_name] = []
                predictions_dict[song_name].append(predictions[idx].item())
            correct += (predictions == labels).sum()
            
        test_loss /= len(test_loader)
        test_losses.append(test_loss)
        print(f"Test Set: Avg Loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} ({(100. * correct / len(test_loader.dataset)):.0f}%)\n")
        return predictions_dict

# %%
test_loss_arr = []
pd = validate(validate_data_loader, test_loss_arr)
# Out:
# Test Set: Avg Loss: 0.6865, Accuracy: 2194/4007 (55%)

# %%
getSongPredictions = lambda arr: 1 if sum(arr) > len(arr) / 2 else 0
for key in pd:
    print(key, getSongPredictions(pd[key]))
# Out:
# Thick As A Brick.mp3 1
# 05_The_Afternoon_a_Afternoon_b_Evening.mp3 1
# 1945_Harry_James_and_Kitty_Kallen_It's_Been_A_Long_Long_Time.mp3 1
# Ed-Sheeran---Shape-of-You.mp3 1
# 1981_Kim_Carnes_Bette_Davis_Eyes.mp3 1
# 05-Phallus Dei.mp3 1
# 11 - Your Lucky Day In Hell.mp3 1
# K-Pop_1.mp3 1
# 01 Play Your Part (Pt. 1).mp3 1
# 01 Close to the Edge I. The Solid Time of Change II. Total Mass Retain III.  I GetUp I Get Down IV. Seasons of Man).mp3 1
# Metro_Boomin_On_Time.mp3 1
# 01Al Di Meola - Flight over Rio.mp3 1
# 04 - Big Shot.mp3 1
# 01_Yours Is No Disgrace.mp3 1
# The Weeknd - The Birds (Trilogy).mp3 1
# Khalil_Fong_Love_in_this_world.mp3 1
# 01. The Light.mp3 1
# 03Uriah Heep - July Morning.mp3 1
# 101-tom_petty_and_the_heartbreakers-refugee.mp3 1
# 02 - Petrichrist.mp3 1
# 2020_BTS_Dynamite.mp3 1
# 05. When the Water Breaks.mp3 1
# Lizzo_Juice.mp3 1
# 01. Hazard Profile Part One.mp3 1
# 1-03 Wonderwall.mp3 1
# 03-genesis-firth_of_fifth.mp3 1
# 03 Midnight At The Bazaar.mp3 1
# ...

# %%
def plot_data(snippet, sr):
    new_snip = snippet.detach().squeeze_(0).numpy()
    mel_spec = new_snip[:120, :]
    print(f"Mel-Spectogram: {mel_spec.shape}")
    mfcc = new_snip[120 : 120+28, :]
    print(f"MFCC: {mfcc.shape}")
    chroma = new_snip[120 + 28: new_snip.shape[0], :]
    print(f"Chromagram: {chroma.shape}")
    
    # Spectrogram
    plt.figure(figsize=(12, 8))
    plt.suptitle("Features")
    # plt.suptitle("{}".format("Progressive Rock" if 0 else "Non-Progressive Rock"))
    
    plt.subplot(4, 2, 1)
    librosa.display.specshow(librosa.power_to_db(mel_spec, ref=np.max), sr=sr, x_axis='time', y_axis='mel')
    plt.title('Mel-Spectrogram')
    plt.colorbar(format='%+2.0f dB')
    
    # Plot the MFCCs
    plt.subplot(4, 2, 2)
    librosa.display.specshow(mfcc, sr=sr, x_axis='time')
    plt.title('MFCC')
    plt.colorbar()
    
    # Plot the chromagram
    plt.subplot(4, 2, 3)
    librosa.display.specshow(chroma, sr=sr, x_axis='time', y_axis='chroma')
    plt.title('Chromagram')
    plt.colorbar()

    # # Plot the beats
    # plt.subplot(4, 2, 4)
    # plt.plot(librosa.frames_to_time(np.arange(len(onset_env))))
    # plt.vlines(librosa.frames_to_time(beat_frames), 0, 1, alpha=0.5, color='r', linestyle='--', label='Beats')
    # plt.legend(loc='upper right')
    # plt.title('Beats')
    
    plt.tight_layout()
    plt.show()

plot_data(train_features[7], 11025)
# Out:
# Mel-Spectogram: (120, 216)
# MFCC: (28, 216)
# Chromagram: (12, 216)

# %%
torch.save(dataset, './train_dataset')
